# %%
import pandas as pd
import joblib

# %%
model = joblib.load("shipment_delay_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = joblib.load("shipment_delay_model.pkl")
#
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
# ...

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
import joblib

# %%
model = joblib.load("shipment_delay_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = joblib.load("shipment_delay_model.pkl")
#
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
# ...

# %%
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
model.feature_names_in_
# Out:
# array(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated',
#        'Customer demographics', 'Stock levels', 'Lead times',
#        'Order quantities', 'Shipping times', 'Shipping carriers',
#        'Shipping costs', 'Supplier name', 'Location', 'Lead time',
#        'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'], dtype='<U23')

# %%
new_shipment = pd.DataFrame({
    "Product type": ["skincare"],
    "SKU": ["SKU101"],
    "Price": [55.5],
    "Availability": [120],
    "Number of products sold": [300],
    "Revenue generated": [4500.75],
    "Customer demographics": ["Female"],
    "Stock levels": [60],
    "Lead times": [12],
    "Order quantities": [150],
    "Shipping times": [7],
    "Shipping carriers": ["Carrier A"],
    "Shipping costs": [80.5],
    "Supplier name": ["Supplier X"],
    "Location": ["Mumbai"],
    "Lead time": [12],
    "Production volumes": [500],
    "Manufacturing lead time": [10],
    "Manufacturing costs": [250.75],
    "Inspection results": ["Pass"],
    "Defect rates": [2.5],
    "Transportation modes": ["Road"],
    "Routes": ["Route A"],
    "Costs": [300.25]
})

# %%
prediction = model.predict(new_shipment)
prediction
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\xgboost\data.py:402, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     401 try:
# --> 402     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     403 except KeyError:
#
# KeyError: 'str'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 prediction = model.predict(new_shipment)
#       2 prediction
#
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\xgboost\core.py:553, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     551 for k, arg in zip(sig.parameters, args):
#     552     kwargs[k] = arg
# --> 553 return func(**kwargs)
#
# ...

# %%
X_train.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 X_train.columns
#
# NameError: name 'X_train' is not defined

# %%
X_train.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X_train.columns
#
# NameError: name 'X_train' is not defined

# %%
new_shipment.dtypes
# Out:
# Product type                   str
# SKU                            str
# Price                      float64
# Availability                 int64
# Number of products sold      int64
# Revenue generated          float64
# Customer demographics          str
# Stock levels                 int64
# Lead times                   int64
# Order quantities             int64
# Shipping times               int64
# Shipping carriers              str
# Shipping costs             float64
# Supplier name                  str
# Location                       str
# Lead time                    int64
# Production volumes           int64
# Manufacturing lead time      int64
# Manufacturing costs        float64
# Inspection results             str
# Defect rates               float64
# Transportation modes           str
# Routes                         str
# Costs                      float64
# dtype: object

# %%
type(model)
# Out:
# xgboost.sklearn.XGBClassifier

# %%
new_shipment.dtypes
# Out:
# Product type                   str
# SKU                            str
# Price                      float64
# Availability                 int64
# Number of products sold      int64
# Revenue generated          float64
# Customer demographics          str
# Stock levels                 int64
# Lead times                   int64
# Order quantities             int64
# Shipping times               int64
# Shipping carriers              str
# Shipping costs             float64
# Supplier name                  str
# Location                       str
# Lead time                    int64
# Production volumes           int64
# Manufacturing lead time      int64
# Manufacturing costs        float64
# Inspection results             str
# Defect rates               float64
# Transportation modes           str
# Routes                         str
# Costs                      float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../dataset/supply_chain_data.csv")

# %%
label_encoders = {}

for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_14576\61030170.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include="object").columns:

# %%
for col in label_encoders:
    new_shipment[col] = label_encoders[col].transform(
        new_shipment[col].astype(str)
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\sklearn\utils\_encode.py:229, in _encode(values, uniques, check_unknown)
#     228 try:
# --> 229     return _map_to_integer(values, uniques)
#     230 except KeyError as e:
#
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\sklearn\utils\_encode.py:168, in _map_to_integer(values, uniques)
#     167 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 168 return xp.asarray([table[v] for v in values], device=device(values))
#
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\sklearn\utils\_encode.py:161, in _nandict.__missing__(self, key)
#     160     return self.nan_value
# --> 161 raise KeyError(key)
#
# KeyError: 'SKU101'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.head()
# Out:
#    Product type  SKU      Price  Availability  Number of products sold  \
# 0             1    0  69.808006            55                      802
# 1             2    1  14.843523            95                      736
# 2             1   12  11.319683            34                        8
# 3             2   23  61.163343            68                       83
# 4             2   34   4.805496            26                      871
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
# 4        2686.505152                      2             5           3
#
#    Order quantities  ...  Location  Lead time  Production volumes  \
# ...

# %%
new_shipment = pd.DataFrame({
    "Product type": [1],
    "SKU": [0],
    "Price": [69.808006],
    "Availability": [55],
    "Number of products sold": [802],
    "Revenue generated": [8661.996792],
    "Customer demographics": [2],
    "Stock levels": [58],
    "Lead times": [7],
    "Order quantities": [96],
    "Shipping times": [4],
    "Shipping carriers": [2],
    "Shipping costs": [2.956572],
    "Supplier name": [0],
    "Location": [4],
    "Lead time": [29],
    "Production volumes": [215],
    "Manufacturing lead time": [29],
    "Manufacturing costs": [46.279879],
    "Inspection results": [2],
    "Defect rates": [0.226410],
    "Transportation modes": [2],
    "Routes": [1],
    "Costs": [187.752075]
})

# %%
new_shipment
# Out:
#    Product type  SKU      Price  Availability  Number of products sold  \
# 0             1    0  69.808006            55                      802
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
#
#    Order quantities  ...  Location  Lead time  Production volumes  \
# 0                96  ...         4         29                 215
#
#    Manufacturing lead time  Manufacturing costs  Inspection results  \
# 0                       29            46.279879                   2
#
#    Defect rates  Transportation modes  Routes       Costs
# 0       0.22641                     2       1  187.752075
#
# [1 rows x 24 columns]

# %%
prediction = model.predict(new_shipment)
prediction
# Out:
# array([0])

# %%
if prediction[0] == 1:
    print("🚚 Shipment will be Delayed")
else:
    print("✅ Shipment will Arri On Time")
# Out:
# ✅ Shipment will Arrive On Time

# %%
from xgboost import XGBClassifier
import joblib
import os

# Train the model
model = XGBClassifier(
    random_state=42,
    eval_metric="logloss"
)

model.fit(X_train, y_train)

# Create models folder if it doesn't exist
os.makedirs("models", exist_ok=True)

# Save the trained model
joblib.dump(model, "models/shipment_delay_model.pkl")

print("✅ Model trained successfully!")
print("✅ Model saved at: models/shipment_delay_model.pkl")
