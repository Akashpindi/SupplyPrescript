# %%
import joblib

# %%
label_encoders = joblib.load("models/label_encoders.pkl")

# %%
print(label_encoders.keys())
# Out:
# dict_keys(['Product type', 'Customer demographics', 'Shipping carriers', 'Location', 'Inspection results', 'Transportation modes', 'Routes'])

# %%
import joblib

model = joblib.load("models/shipment_delay_model.pkl")

print(model.feature_names_in_)
# Out:
# ['Product type' 'Price' 'Availability' 'Number of products sold'
#  'Revenue generated' 'Customer demographics' 'Stock levels' 'Lead times'
#  'Order quantities' 'Shipping times' 'Shipping carriers' 'Shipping costs'
#  'Location' 'Lead time' 'Production volumes' 'Manufacturing lead time'
#  'Manufacturing costs' 'Inspection results' 'Defect rates'
#  'Transportation modes' 'Routes' 'Costs']

# %%
print(len(model.feature_names_in_))
# Out:
# 22

# %%
import joblib
import xgboost

print(joblib.__version__)
print(xgboost.__version__)
# Out:
# 1.5.3
# 3.3.0

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\shiva\machine-learning\venv\Scripts\python.exe

# %%
import joblib

model = joblib.load("models/shipment_delay_model.pkl")

joblib.dump(model, "models/shipment_delay_model_new.pkl")

print("New model saved succesfully!")
# Out:
# New model saved successfully!

# %%
import joblib

model = joblib.load("models/shipment_delay_model.pkl")

joblib.dump(model, "models/shipment_delay_model_new.pkl")

print("New model saved successfully!")
# Out:
# New model saved successfully!

# %%
import os

print(os.listdir("models"))
# Out:
# ['feature_importance.csv', 'label_encoders.pkl', 'shipment_delay_model.pkl', 'shipment_delay_model_new.pkl']

# %%
print(os.listdir("models"))
# Out:
# ['feature_importance.csv', 'label_encoders.pkl', 'shipment_delay_model.pkl', 'shipment_delay_model_new.pkl']

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\shiva\machine-learning\notebooks

# %%
import joblib

model = joblib.load("../models/shipment_delay_model.pkl")

joblib.dump(
    model,
    r"C:\Users\shiva\machine-learning\models\shipment_delay_model_new.pkl"
)

print("Model saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 import joblib
#       2
# ----> 3 model = joblib.load("../models/shipment_delay_model.pkl")
#       4
#       5 joblib.dump(
#       6     model,
#
# File c:\Users\shiva\machine-learning\venv\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
# ...
