# %%
import joblib
import pandas as pd

# %%
model = joblib.load("models/shipment_delay_model.pkl")
label_encoders = joblib.load("models/label_encoders.pkl")

# %%
new_data = pd.DataFrame({
    "Product type": ["skincare"],
    "Price": [50],
    "Availability": [100],
    "Number of products sold": [50],
    "Revenue generated": [1000],
    "Customer demographics": ["Female"],
    "Stock levels": [150],
    "Lead times": [5],
    "Order quantities": [50],
    "Shipping times": [4],
    "Shipping carriers": ["Carrier A"],
    "Shipping costs": [200],
    "Location": ["Mumbai"],
    "Lead time": [5],
    "Production volumes": [300],
    "Manufacturing lead time": [10],
    "Manufacturing costs": [500],
    "Inspection results": ["Pass"],
    "Defect rates": [2.5],
    "Transportation modes": ["Road"],
    "Routes": ["Route A"],
    "Costs": [1000]
})

# %%
categorical_columns = [
    "Product type",
    "Customer demographics",
    "Shipping carriers",
    "Location",
    "Inspection results",
    "Transportation modes",
    "Routes"
]

for col in categorical_columns:
    new_data[col] = label_encoders[col].transform(new_data[col])

# %%
prediction = model.predict(new_data)
probability = model.predict_proba(new_data)

# %%
print("Prediction:", prediction[0])

if prediction[0] == 1:
    print("Shipment will be Delayyed")
else:
    print("Shipment will NOT be Delayed")

print(f"Probability of Not Delayed: {probability[0][0]:.2f}")
print(f"Probability of Delayd: {probability[0][1]:.2f}")
# Out:
# Prediction: 0
# Shipment will NOT be Delayed
# Probability of Not Delayed: 0.97
# Probability of Delayed: 0.03
